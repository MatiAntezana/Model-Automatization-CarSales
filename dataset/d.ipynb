# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('pf_suvs_i302_1s2024.csv')
df
# Out:
#          Marca Modelo     Año                     Versión   Color  \
# 0      Peugeot   2008  2022.0         1.6 Feline Tip am20  Blanco
# 1      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 2      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 3      Peugeot   2008  2018.0                  1.6 Feline  Blanco
# 4      Peugeot   2008  2016.0               1.6 Thp Sport    Gris
# ...        ...    ...     ...                         ...     ...
# 22372    Volvo   XC60  2012.0    2.0 T5 Awd Comfort 240cv    Gris
# 22373    Volvo   XC60  2020.0      3.0 T6 High Luxury Awd   Negro
# 22374    Volvo   XC60  2018.0          2.5 T5 Inscription   Negro
# 22375    Volvo   XC60  2012.0  2.0 T5 Awd High Plus 240cv   Negro
# 22376    Volvo   XC60  2017.0          2.0 T5 Inscription    Gris
#
#       Tipo de combustible  Puertas Transmisión Motor Tipo de carrocería  \
# 0                   Nafta      5.0  Automática   1.6                SUV
# ...

# %%
df = df.drop_duplicates().reset_index(drop=True)
df
# Out:
#          Marca Modelo     Año                     Versión   Color  \
# 0      Peugeot   2008  2022.0         1.6 Feline Tip am20  Blanco
# 1      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 2      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 3      Peugeot   2008  2018.0                  1.6 Feline  Blanco
# 4      Peugeot   2008  2016.0               1.6 Thp Sport    Gris
# ...        ...    ...     ...                         ...     ...
# 21746    Volvo   XC60  2012.0    2.0 T5 Awd Comfort 240cv    Gris
# 21747    Volvo   XC60  2020.0      3.0 T6 High Luxury Awd   Negro
# 21748    Volvo   XC60  2018.0          2.5 T5 Inscription   Negro
# 21749    Volvo   XC60  2012.0  2.0 T5 Awd High Plus 240cv   Negro
# 21750    Volvo   XC60  2017.0          2.0 T5 Inscription    Gris
#
#       Tipo de combustible  Puertas Transmisión Motor Tipo de carrocería  \
# 0                   Nafta      5.0  Automática   1.6                SUV
# ...

# %%
# Convertir los kilómetros a enteros
df['Kilómetros'] = df['Kilómetros'].str.replace(' km', '').str.replace('.', '').astype(int)
df
# Out:
# C:\Users\elmat\AppData\Local\Temp\ipykernel_22056\1455288787.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Kilómetros'] = df['Kilómetros'].str.replace(' km', '').str.replace('.', '').astype(int)
#          Marca Modelo     Año                     Versión   Color  \
# 0      Peugeot   2008  2022.0         1.6 Feline Tip am20  Blanco
# 1      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 2      Peugeot   2008  2021.0                  1.6 Allure  Marrón
# 3      Peugeot   2008  2018.0                  1.6 Feline  Blanco
# 4      Peugeot   2008  2016.0               1.6 Thp Sport    Gris
# ...        ...    ...     ...                         ...     ...
# 21746    Volvo   XC60  2012.0    2.0 T5 Awd Comfort 240cv    Gris
# 21747    Volvo   XC60  2020.0      3.0 T6 High Luxury Awd   Negro
# ...

# %%
# Obtener todos los modelos de Tracker que sen 0km
df2 = df[(df['Modelo'] == 'Tracker') & (df['Kilómetros'] == 0) & (df['Año'] == 2021)]
df2
# Out:
#            Marca   Modelo     Año               Versión     Color  \
# 18820  Chevrolet  Tracker  2021.0  1.2 Premier Turbo At      Gris
# 18839  Chevrolet  Tracker  2021.0  1.2 Premier Turbo At    Blanco
# 18982  Chevrolet  Tracker  2021.0  1.2 Premier Turbo At      Azul
# 18983  Chevrolet  Tracker  2021.0      1.2 Ltz Turbo At    Blanco
# 19244  Chevrolet  Tracker  2021.0          1.2 Turbo Mt    Blanco
# 19340  Chevrolet  Tracker  2021.0          1.2 Turbo Mt    Blanco
# 19468  Chevrolet  Tracker  2021.0          1.2 Turbo At    Blanco
# 19555  Chevrolet  Tracker  2021.0          1.2 Turbo Mt    Blanco
# 19569  Chevrolet  Tracker  2021.0  1.2 Premier Turbo At  Plateado
# 19590  Chevrolet  Tracker  2021.0          1.2 Turbo At  A elegir
# 19612  Chevrolet  Tracker  2021.0  1.2 Premier Turbo At       NaN
#
#       Tipo de combustible  Puertas Transmisión Motor Tipo de carrocería  \
# 18820               Nafta      5.0  Automática   1.2                SUV
# ...
