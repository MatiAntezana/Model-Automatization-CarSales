# %%
from process_data import *

filename = 'dataset/pf_suvs_i302_1s2024.csv'

data = read_data(filename)

dic_data = identify_type_cars(data)

print(data[0])
# Out:
# ['Peugeot' '2008' 2022.0 '1.6 Feline Tip am20' 'Blanco' 'Nafta' 5.0
#  'Automática' '1.6' 'SUV' '23000 km' 'Peugeot 2008 1.6 Feline Tip am20'
#  22499999.0 '$' 'tienda' nan]
